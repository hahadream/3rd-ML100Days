# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[256, 128, 64]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units = n_units, activation = 'relu')(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units = n_units, activation = 'relu')(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units = output_units, activation = 'softmax')(x)
    
    model = keras.models.Model(inputs = [input_layer], outputs = [out])
    
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 20
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

import numpy as np
from sklearn.metrics import confusion_matrix

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def on_train_begin(self, epochs, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epochs, logs = {}, thres = 0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs['val_tp'] = np.diag(confusion_matrix(y_true, y_pred)).sum()
          
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (x_test, y_test), shuffle = True, callbacks = [rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# dense_33 (Dense)             (None, 256)               786688
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 128)               512
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 64)                256
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                650
# =================================================================
# Total params: 830,282
# Trainable params: 829,386
# Non-trainable params: 896
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 6s 111us/step - loss: 2.2983 - accuracy: 0.2397 - val_loss: 2.1346 - val_accuracy: 0.2241
# Epoch 2/20
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.8314 - accuracy: 0.3628 - val_loss: 1.9671 - val_accuracy: 0.3055
# Epoch 3/20
# 50000/50000 [==============================] - 6s 117us/step - loss: 1.7080 - accuracy: 0.4022 - val_loss: 1.8714 - val_accuracy: 0.3461
# Epoch 4/20
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.6387 - accuracy: 0.4260 - val_loss: 1.7700 - val_accuracy: 0.3884
# Epoch 5/20
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.5883 - accuracy: 0.4424 - val_loss: 1.6997 - val_accuracy: 0.4134
# Epoch 6/20
# 50000/50000 [==============================] - 6s 117us/step - loss: 1.5480 - accuracy: 0.4570 - val_loss: 1.6543 - val_accuracy: 0.4260
# Epoch 7/20
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.5130 - accuracy: 0.4695 - val_loss: 1.6114 - val_accuracy: 0.4350
# Epoch 8/20
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4836 - accuracy: 0.4793 - val_loss: 1.5866 - val_accuracy: 0.4399
# Epoch 9/20
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.4557 - accuracy: 0.4912 - val_loss: 1.5720 - val_accuracy: 0.4469
# Epoch 10/20
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.4301 - accuracy: 0.4985 - val_loss: 1.5393 - val_accuracy: 0.4602
# Epoch 11/20
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.4074 - accuracy: 0.5075 - val_loss: 1.5287 - val_accuracy: 0.4630
# Epoch 12/20
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.3858 - accuracy: 0.5144 - val_loss: 1.5126 - val_accuracy: 0.4702
# Epoch 13/20
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.3650 - accuracy: 0.5221 - val_loss: 1.5060 - val_accuracy: 0.4722
# Epoch 14/20
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.3465 - accuracy: 0.5273 - val_loss: 1.5014 - val_accuracy: 0.4707
# Epoch 15/20
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.3298 - accuracy: 0.5349 - val_loss: 1.5047 - val_accuracy: 0.4700
# Epoch 16/20
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.3099 - accuracy: 0.5423 - val_loss: 1.4885 - val_accuracy: 0.4784
# Epoch 17/20
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2925 - accuracy: 0.5466 - val_loss: 1.4896 - val_accuracy: 0.4793
# Epoch 18/20
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2766 - accuracy: 0.5528 - val_loss: 1.4926 - val_accuracy: 0.4720
# Epoch 19/20
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.2592 - accuracy: 0.5587 - val_loss: 1.4883 - val_accuracy: 0.4749
# Epoch 20/20
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2439 - accuracy: 0.5654 - val_loss: 1.4650 - val_accuracy: 0.4852

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.legend()
plt.title("True positives")
plt.show()
