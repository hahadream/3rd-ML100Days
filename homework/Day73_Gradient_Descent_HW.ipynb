# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 100000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function 
iters = 0 
lr = 0.1
previous_step_size = 1 

iters_history1 = [iters]
x_history1 = [cur_x]

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
# Out:
# '\nwhile previous_step_size > precision and iters < max_iters:\n\n  算法迭代更新\n\nprint("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations\n'

# %%
while previous_step_size > precision and iters < max_iters: 
    prev_x = cur_x
    cur_x = cur_x - lr * df(cur_x)
    previous_step_size = abs(prev_x - cur_x)
    iters += 1 
    iters_history1.append(iters)
    x_history1.append(cur_x)
print("Total number of iterations:", iters, "\nThe local minimum occurs at:", cur_x)
# Out:
# Total number of iterations: 66
# The local minimum occurs at: -4.999996786123911

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 100000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function 
iters = 0 
lr = 0.01
previous_step_size = 1 

iters_history2 = [iters]
x_history2 = [cur_x]

# %%
while previous_step_size > precision and iters < max_iters: 
    prev_x = cur_x
    cur_x = cur_x - lr * df(cur_x)
    previous_step_size = abs(prev_x - cur_x)
    iters += 1 
    iters_history2.append(iters)
    x_history2.append(cur_x)
print("Total number of iterations:", iters, "\nThe local minimum occurs at:", cur_x)
# Out:
# Total number of iterations: 595
# The local minimum occurs at: -4.9999518490318176

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 100000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function 
iters = 0 
lr = 0.0001
previous_step_size = 1 

iters_history3 = [iters]
x_history3 = [cur_x]

# %%
while previous_step_size > precision and iters < max_iters: 
    prev_x = cur_x
    cur_x = cur_x - lr * df(cur_x)
    previous_step_size = abs(prev_x - cur_x)
    iters += 1 
    iters_history3.append(iters)
    x_history3.append(cur_x)
print("Total number of iterations:", iters, "\nThe local minimum occurs at:", cur_x)
# Out:
# Total number of iterations: 36887
# The local minimum occurs at: -4.995001894291844

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize = (6,18))
ax1.plot(iters_history1, x_history1)
ax1.set_xlabel("Number of iterations")
ax1.set_ylabel("Value of x")
ax1.set_title("Plot for lr = 0.1")
ax2.plot(iters_history2, x_history2)
ax2.set_xlabel("Number of iterations")
ax2.set_ylabel("Value of x")
ax2.set_title("Plot for lr = 0.01")
ax3.plot(iters_history3, x_history3)
ax3.set_xlabel("Number of iterations")
ax3.set_ylabel("Value of x")
ax3.set_title("Plot for lr = 0.0001")
# Out:
# Text(0.5, 1.0, 'Plot for lr = 0.0001')
